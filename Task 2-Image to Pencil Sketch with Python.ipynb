# %% [markdown]
# # Name : Sharvari Sunil Mangale

# %% [markdown]
# # LGM Virtual Internship Program - October 2021
#
# # Data Science - Beginner Level
#
# # Task 2 : Image to Pencil Sketch with Python

# %% [markdown]
# **Importing Libraries**

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# # Read Photo

# %%
img=cv2.imread("image1.jpg")

# %% [markdown]
# # Show Image using OpenCV

# %%
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=900x580 at 0x7F99031ACE10>

# %% [markdown]
# # Display Using Matplotlib

# %%
plt.imshow(img)
plt.axis(False)
plt.show()

# %% [markdown]
# # Convert to Grey Image

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=900x580 at 0x7F9903075A50>

# %% [markdown]
# # Invert Image

# %%
invert_img=cv2.bitwise_not(grey_img)

# %%
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=900x580 at 0x7F990308ACD0>

# %% [markdown]
# # Blur image

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)

# %%
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=900x580 at 0x7F99030CD210>

# %% [markdown]
# # Sketch

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)

# %% [markdown]
# # Save Sketch

# %%
cv2.imwrite("save.png",sketch_img)
# Out:
# True

# %% [markdown]
# # Display sketch

# %%
cv2_imshow(sketch_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=900x580 at 0x7F990308A990>

# %% [markdown]
# # THANK YOU
